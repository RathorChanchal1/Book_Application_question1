# %% [markdown]
# <a href="https://colab.research.google.com/github/RathorChanchal1/Book_Application_question1/blob/main/btp_project_milling_process.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
from sklearn import model_selection

# %%
pip install lazypredict

# %%
# Imports
from lazypredict.Supervised import LazyRegressor
from sklearn.model_selection import train_test_split
import pandas as pd
from sklearn import datasets

# %%
data = pd.read_csv("/content/forceData.csv")

# %%
data
# Out:
#            Run_ID  Experiment  Replica  Tool_ID  Group  Subgroup Position  \
# 0    1_021_B1_4_a           1        1       21      1         2        a
# 1    1_021_B1_6_b           1        1       21      1         2        b
# 2    1_021_B1_5_c           1        1       21      1         2        c
# 3    1_021_B1_8_d           1        1       21      1         3        d
# 4    1_021_B1_9_e           1        1       21      1         3        e
# 5    1_021_B1_7_f           1        1       21      1         3        f
# 6    1_021_B1_2_g           1        1       21      1         1        g
# 7    1_021_B1_1_h           1        1       21      1         1        h
# 8    1_021_B1_3_i           1        1       21      1         1        i
# 9   1_031_B2_10_b           1        1       31      2         4        b
# 10  1_031_B2_12_c           1        1       31      2         4        c
# 11  1_031_B2_11_d           1        1       31      2         4        d
# ...

# %%
df = data[['ap', 'vc', 'f', 'Fx', 'Fy', 'Fz', 'F']]

# %%
df
# Out:
#      ap   vc    f     Fx     Fy     Fz      F
# 0  0.25  350 0.07  49.23  44.46  21.07  69.60
# 1  0.25  350 0.13  81.03  59.21  25.94 103.66
# 2  0.25  350 0.10  65.48  49.71  22.31  85.18
# 3  0.25  390 0.10  65.95  50.85  22.30  86.21
# 4  0.25  390 0.13  84.34  57.88  26.26 105.61
# 5  0.25  390 0.07  51.59  42.31  18.87  69.34
# 6  0.25  310 0.10  69.13  50.07  20.51  87.79
# 7  0.25  310 0.07  55.44  41.60  19.53  72.01
# 8  0.25  310 0.13  84.61  56.61  24.09 104.61
# 9  0.50  310 0.07 110.50  61.45  68.08 143.60
# 10 0.50  310 0.13 171.50  83.49  75.56 205.16
# 11 0.50  310 0.10 141.50  69.27  67.71 171.48
# 12 0.50  390 0.10 141.90  70.27  65.19 171.24
# 13 0.50  390 0.07 110.10  56.55  61.05 138.01
# 14 0.50  390 0.13 173.50  82.13  71.80 204.95
# 15 0.50  350 0.10 144.70  70.44  66.44 174.11
# 16 0.50  350 0.13 179.80  81.93  75.26 211.43
# 17 0.50  350 0.07 107.70  52.78  60.21 134.20
# 18 0.80  350 0.07 159.50  62.91 115.80 206.90
# ...

# %%
X = df[['ap', 'vc', 'f']]
y = df['F']
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2,random_state=12)
# Fit all regression models
reg = LazyRegressor(predictions=True)
models, predictions = reg.fit(X_train, X_test, y_train, y_test)
models
# Out:
# 100%|██████████| 42/42 [00:01<00:00, 32.43it/s]
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 43, number of used features: 0
# [LightGBM] [Info] Start training from score 179.946446
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# ...

# %%
predictions
# Out:
#     AdaBoostRegressor  BaggingRegressor  BayesianRidge  DecisionTreeRegressor  \
# 0              159.49            173.39         180.87                 174.11
# 1              319.61            309.08         295.42                 295.91
# 2              223.46            229.84         257.94                 224.23
# 3               76.96             73.36          40.63                  73.84
# 4              366.32            349.11         332.90                 369.26
# 5              158.40            141.20         139.74                 141.15
# 6              104.37            104.22         126.55                 103.66
# 7              208.24            206.35         218.35                 205.16
# 8              366.32            349.11         332.90                 369.26
# 9              208.24            208.23         222.00                 211.43
# 10             208.24            206.91         225.65                 204.95
#
# ...

# %%
y_test.reset_index(drop=True, inplace=True)
pd.set_option('display.max_rows', None)
predictions["y_test"]=y_test
predictions
# Out:
#     AdaBoostRegressor  BaggingRegressor  BayesianRidge  DecisionTreeRegressor  \
# 0              159.49            173.39         180.87                 174.11
# 1              319.61            309.08         295.42                 295.91
# 2              223.46            229.84         257.94                 224.23
# 3               76.96             73.36          40.63                  73.84
# 4              366.32            349.11         332.90                 369.26
# 5              158.40            141.20         139.74                 141.15
# 6              104.37            104.22         126.55                 103.66
# 7              208.24            206.35         218.35                 205.16
# 8              366.32            349.11         332.90                 369.26
# 9              208.24            208.23         222.00                 211.43
# 10             208.24            206.91         225.65                 204.95
#
# ...

# %%
name='GradientBoostingRegressor'    # put name which you want to see here
# to check Observed Vs predicted
df1=pd.DataFrame()
df1['Orignal']=y_test
a=df1.index
df1.reset_index(drop=True, inplace=True)
df1[name]=predictions[name]
df1['Deviation']=abs(df1['Orignal']-df1[name])
# df1['Battery No.']=a
print( ' for Model :', name)
df1=df1.sort_values(by='Deviation')
df1.head(50)
# Out:
#  for Model : GradientBoostingRegressor
#     Orignal  GradientBoostingRegressor  Deviation
# 3     72.01                      73.43       1.42
# 8    377.57                     376.08       1.49
# 6    102.97                     105.19       2.21
# 4    373.46                     376.08       2.62
# 9    212.35                     209.17       3.18
# 10   209.42                     206.02       3.40
# 0    174.82                     171.22       3.60
# 7    213.61                     206.38       7.24
# 5    134.20                     141.64       7.43
# 2    209.31                     225.28      15.96
# 1    331.78                     307.06      24.72

# %%
import matplotlib.pyplot as plt

# Data from the table
indices = [3, 8, 6, 4, 9, 10, 0, 7, 5, 2, 1]
original_values = [72.01, 377.57, 102.97, 373.46, 212.35, 209.42, 174.82, 213.61, 134.20, 209.31, 331.78]
gradient_boosting_values = [73.43, 376.08, 105.19, 376.08, 209.17, 206.02, 171.22, 206.38, 141.64, 225.28, 307.06]

# Plotting the data
plt.figure(figsize=(10, 6))
plt.scatter(indices, original_values, marker='o', label='Original Value')
plt.scatter(indices, gradient_boosting_values, marker='x', label='GradientBoosting Value')
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('Original Value vs. GradientBoosting Value')
plt.legend()
plt.grid(True)
plt.show()

# %%
name='RandomForestRegressor'    # put name which you want to see here
# to check Observed Vs predicted
df1=pd.DataFrame()
df1['Orignal']=y_test
a=df1.index
df1.reset_index(drop=True, inplace=True)
df1[name]=predictions[name]
df1['Deviation']=abs(df1['Orignal']-df1[name])
# df1['Battery No.']=a
print( ' for Model :', name)
df1=df1.sort_values(by='Deviation')
df1.head(50)
# Out:
#  for Model : RandomForestRegressor
#     Orignal  RandomForestRegressor  Deviation
# 6    102.97                 103.85       0.87
# 3     72.01                  73.04       1.03
# 0    174.82                 173.42       1.40
# 10   209.42                 205.18       4.24
# 9    212.35                 207.61       4.74
# 4    373.46                 367.05       6.42
# 5    134.20                 141.08       6.88
# 7    213.61                 205.48       8.14
# 8    377.57                 367.05      10.52
# 2    209.31                 221.28      11.97
# 1    331.78                 307.28      24.49

# %%
import matplotlib.pyplot as plt

# Data from the table
indices = [6, 3, 0, 10, 9, 4, 5, 7, 8, 2, 1]
original_values = [102.97, 72.01, 174.82, 209.42, 212.35, 373.46, 134.20, 213.61, 377.57, 209.31, 331.78]
random_forest_values = [103.85, 73.04, 173.42, 205.18, 207.61, 367.05, 141.08, 205.48, 367.05, 221.28, 307.28]

# Plotting the data
plt.figure(figsize=(10, 6))
plt.scatter(indices, original_values, marker='o', label='Original Value')
plt.scatter(indices, random_forest_values, marker='x', label='RandomForestRegressor Value')
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('Original Value vs. RandomForestRegressor Value')
plt.legend()
plt.grid(True)
plt.show()
